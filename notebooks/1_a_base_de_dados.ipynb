# %% [markdown]
# <center> <h1> <b> A Base de Dados </b> </h1> </center>
#
# ___

# %% [markdown]
# Quando vamos fazer uma análise, o **problema** é a primeira coisa que temos que definir. E o que isso significa? Significa que a base - ou bases - de dados utilizada deve ter como objetivo auxiliar na resolução desse problema.
#
# > A base de dados utilizada deve servir ao problema proposto, não o contrário.
#
# Dito isso, a base que irei utilizar nos exemplos é aleatória, onde meu único critério de escolha foi eu considerar uma base interessante e que dê para realizar diferentes análises. Ou seja, eu não tenho um **problema inicial**, por isso a escolha da base foi arbitrária, servindo apenas como exemplo para as análises estatísticas.

# %% [markdown]
# <center> <h2> Radar IDHM </h2> </center>
#
# O [Radar IDHM](http://www.atlasbrasil.org.br/2013/en/radar-idhm/) é um estudo do IBGE realizado com base na Pesquisa Nacional de Amostragem de Domicílios (PNAD) e auxilia na atualização dos dados do [Atlas do Desenvolvimento no Brasil](http://www.atlasbrasil.org.br/2013/pt/o_atlas/o_atlas_/). </br>
# O Atlas é um site voltado à consulta ao Índice de Desenvolvimento Humano Municipal (IDHM), contando com:
# * 5.565 municípios;
# * 27 Unidades Federativas (UF);
# * 21 Regiões Metropolitanas (RM);
# * 3 Regiões Integradas de Desenvolvimento (RIDE);
#
# O Atlas também traz mais de 200 indicadores com os dados retirados dos Censos de 1991, 2000 e 2010.

# %% [markdown]
# <center> <h2> Rápidas Considerações  </h2> </center>

# %% [markdown]
# Irei passar rápido pela parte de importação da base e conhecimento dos dados que serão utilizados, porém deixando as informações essenciais o mais claro possível, assim como irei sempre explicar muito bem o código utilizado. </br>
# Irei utilizar a base já apresentada, porém apenas com o seguinte recorte: RM/Estado/País; e que pode ser encontrada [aqui](https://bit.ly/2GgtDIM).

# %% [markdown]
# A versão do Python que irei utilizar em todos os notebooks será a 3.7.5 e o sistema operacional Ubuntu 19.10.

# %%
# !python --version
'---'
# !lsb_release -a
# Out:
# Python 3.7.5
# '---'
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 19.10
# Release:	19.10
# Codename:	eoan

# %% [markdown]
# Antes de começar a botar a mão na massa, no início de todos os notebooks, importarei a classe abaixo, que permite rodar mais de um comando por célula, e não apenas o último como é o padrão do *Jupyter Notebook* .

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Para manipulação da base de dados, será utilizada a biblioteca [Pandas](https://pandas.pydata.org/pandas-docs/stable/) do Python e uma das ferramentas mais utilizadas e competentes no que diz respeito ao tratamento de dados em geral. </br>
# Foi necessário realizar a instalação do pacote [`xlrd`](https://pypi.org/project/xlrd/) do Python, especificamente na minha máquina, o que pode ser feito através do PyPI:
# ```python
# !pip install xlrd
# ```

# %% [markdown]
# <center> <h2> Uma rápida, rápida mesmo, visão sobre o Pandas </h2> </center>

# %% [markdown]
# Novamente, o objetivo desse e de futuros artigos é focar no conhecimento estatístico. O Python, ou qualquer outra linguagem de programação, é o que nos permite fazer isso de forma escalonada, com grandes quantidades de dados, e, com isso, é natural sabermos o que e o por que de estarmos realizando certos passos. Por isso, vamos entender um pouco sobre `DataFrame` e `Series` de forma bastante resumida.
# > *`Series`*: é uma estrutura de dados **unidimensional** rotulada e que pode conter mais de um tipo de dado (`int`, `str`, `float`, etc.);</br>
# > *`DataFrame`: é uma estrutura dados de **duas dimensões**, onde os dados são organizados de forma tabular através de **linhas** e **colunas**;
#
# Basicamente, um *DataFrame* (linhas e colunas) nada mais é que um conjunto de *Series* (colunas). E é importante ressaltar que o primeiro valor que o Python considera, começa a contar, é o valor 0, e não 1. </br>

# %%
#importando o Pandas
import pandas as pd

# %%
# criando uma Series através de tuplas com nome A, 3 linhas e 3 valores por linha
series_tup = [(10, 20, 30),
              (10, 20, 30),
              (10, 20, 30)]

# criando uma Series através de listas com nome A, 3 linhas e 3 valores por linha
values_list = [[10, 20, 30],
               [10, 20, 30],
               [10, 20, 30]]

pd.Series(data = series_tup, name = 'A')
pd.Series(data = values_list, name = 'A')
# Out:
# 0    [10, 20, 30]
# 1    [10, 20, 30]
# 2    [10, 20, 30]
# Name: A, dtype: object

# %%
# criando um DataFrame com 3 linhas e 3 colunas (ou Series)
data = [[10, 20, 30],
             [10, 20, 30],
             [10, 20, 30]]

columns = ['A', 'B', 'C']

# transformando data em um dataframe
pd.DataFrame(data, columns = columns)

# selecionando apenas a cluna A do dataframe
pd.DataFrame(data, columns = columns).A

# verificando o tipo do dataframe e do "fatiamento" selecionado
type(pd.DataFrame(data, columns = columns))
type(pd.DataFrame(data, columns = columns).A)
# Out:
#     A   B   C
# 0  10  20  30
# 1  10  20  30
# 2  10  20  30
# 0    10
# 1    10
# 2    10
# Name: A, dtype: int64
# pandas.core.frame.DataFrame
# pandas.core.series.Series

# %% [markdown]
# <center> <h2> Conhecendo a Base  </h2> </center>

# %% [markdown]
# > A primeira planilha/aba do arquivo, possui as definições de cada uma das siglas existentes nas outras planilhas. </br>
# > Fazendo um panorama geral, temos, no mínimo, 68 variáveis diferentes disponibilizadas. Ou seja, cada linha dessa será uma variável nas outras planilhas.

# %%
# importando o Pandas
import pandas as pd

# passando o caminho para um objeto; isso facilita alterações futuras no caminho do arquivo
file_path = 'datasets/idhm_pnadc_2012_2108.xlsx'

# o arquivo possui mais de uma planilha (aba),
# sendo necessário indicar com qual queremos trabalhar

idhm_data = pd.read_excel(file_path, sheet_name = 0) # verificando a primeira aba
idhm_data.head() # 5 primeiras linhas da planilha
idhm_data.info() # dados gerais sobre a planilha
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 4 columns):
# SIGLA         68 non-null object
# NOME CURTO    68 non-null object
# NOME LONGO    68 non-null object
# DEFINIÇÃO     68 non-null object
# dtypes: object(4)
# memory usage: 2.2+ KB

# %% [markdown]
# > Na segunda planilha, temos uma visão geral dos dados em que podemos trabalhar. </br>
# > Ao todo, temos 70 variáveis (colunas) e 294 observações (linhas) por variável. Algumas variáveis contam com apenas 98 observações o que significa que os valores restantes, para igualar aos 294 valores das outras colunas, aparecerão como `NaN` (perdidos/missing). </br>
# > Em relação aos tipos de dados, temos:
# > * 54 variáveis como `float` (decimal);
# > * 14 variáveis como `int` (inteiro);
# > * 2 variáveis como `object` (string);

# %%
idhm_data = pd.read_excel(file_path, sheet_name = 1) # verificando a segunda aba
idhm_data.head()
idhm_data.info()
# Out:
#     Ano NOME_AGREGA SIGLA_AGREGA  AGREGA  ESPVIDA  MORT1  T_ENV  RAZDEP  \
# 0  2012      BRASIL       BRASIL       1    74.52  15.69   8.79   45.77
# 1  2013      BRASIL       BRASIL       1    74.84  15.02   8.96   45.46
# 2  2014      BRASIL       BRASIL       1    75.14  14.40   9.29   44.63
# 3  2015      BRASIL       BRASIL       1    75.44  13.82   9.49   44.10
# 4  2016      BRASIL       BRASIL       1    75.72  13.29   9.84   43.48
#
#    ANOSEST  T_ANALF15M  ...     POP25M    POP65M         POPT     POPTOT  \
# 0     7.54        8.68  ...  120213414  17470255          NaN  198660169
# 1     7.67        8.37  ...  122375322  17967626          NaN  200454809
# 2     7.85        7.98  ...  125709230  18774795          NaN  202194916
# 3     7.98        7.75  ...  127620286  19354194          NaN  203880479
# 4     8.09        7.28  ...  130353863  20216293  202785002.0  205511395
#
#    I_ESCOLARIDADE  I_FREQ_PROP  IDHM_E  IDHM_L  IDHM_R   IDHM
# 0           0.595        0.736   0.686   0.825     NaN    NaN
# 1           0.604        0.749   0.697   0.831     NaN    NaN
# 2           0.618        0.767   0.714   0.836     NaN    NaN
# 3           0.629        0.775   0.723   0.841     NaN    NaN
# 4           0.644        0.792   0.739   0.845   0.748  0.776
#
# [5 rows x 70 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 70 columns):
# Ano                  294 non-null int64
# NOME_AGREGA          294 non-null object
# SIGLA_AGREGA         294 non-null object
# AGREGA               294 non-null int64
# ESPVIDA              294 non-null float64
# MORT1                294 non-null float64
# T_ENV                294 non-null float64
# RAZDEP               294 non-null float64
# ANOSEST              294 non-null float64
# T_ANALF15M           294 non-null float64
# T_ANALF18M           294 non-null float64
# T_ANALF25M           294 non-null float64
# T_ATRASO_2_BASICO    294 non-null float64
# T_ATRASO_2_FUND      294 non-null float64
# T_FLBAS              294 non-null float64
# T_FLFUND             294 non-null float64
# T_FLMED              294 non-null float64
# T_FLSUPER            294 non-null float64
# T_FREQ5A6            294 non-null float64
# T_FREQ6A14           294 non-null float64
# T_FREQ15A17          294 non-null float64
# T_FREQ18A24          294 non-null float64
# T_FUND11A13          294 non-null float64
# T_FUND15A17          294 non-null float64
# T_FUND18M            294 non-null float64
# T_FUND18A24          294 non-null float64
# T_FUND25M            294 non-null float64
# T_MED18A20           294 non-null float64
# T_MED25M             294 non-null float64
# T_SUPER25M           294 non-null float64
# R1040                98 non-null float64
# R2040                98 non-null float64
# RDPC                 98 non-null float64
# V_RENOCUP            294 non-null float64
# RDPC1                98 non-null float64
# RDPC2                98 non-null float64
# RDPC3                98 non-null float64
# RDPC4                98 non-null float64
# RDPC5                98 non-null float64
# RDPC10               98 non-null float64
# RDPCT                98 non-null float64
# RIND                 98 non-null float64
# RMPOB                98 non-null float64
# RPOB                 98 non-null float64
# PRENTRAB             98 non-null float64
# PIND                 98 non-null float64
# PMPOB                98 non-null float64
# PPOB                 98 non-null float64
# GINI                 98 non-null float64
# THEIL                98 non-null float64
# POP                  98 non-null float64
# POP5A6               294 non-null int64
# POP6A14              294 non-null int64
# POP6A17              294 non-null int64
# POP11A13             294 non-null int64
# POP15A17             294 non-null int64
# POP15M               294 non-null int64
# POP18M               294 non-null int64
# POP18A20             294 non-null int64
# POP18A24             294 non-null int64
# POP25M               294 non-null int64
# POP65M               294 non-null int64
# POPT                 98 non-null float64
# POPTOT               294 non-null int64
# I_ESCOLARIDADE       294 non-null float64
# I_FREQ_PROP          294 non-null float64
# IDHM_E               294 non-null float64
# IDHM_L               294 non-null float64
# IDHM_R               98 non-null float64
# IDHM                 98 non-null float64
# dtypes: float64(54), int64(14), object(2)
# memory usage: 160.9+ KB

# %% [markdown]
# > De cara, podemos observar que temos mais observações por coluna e uma variável a mais: `COR`. A princípio, essa aba possui os mesmos dados que a segunda planilha, porém adicionando observações em relação à cor dos indivíduos. </br>
# > Em relação aos tipos de dados, agora temos:
# > * 54 variáveis como `float` (decimal);
# > * 14 variáveis como `int` (inteiro);
# > * 3 variáveis como `object` (string);

# %%
idhm_data = pd.read_excel(file_path, sheet_name = 2) # verificando a terceira aba
idhm_data.head()
idhm_data.info()
# Out:
#     Ano     COR NOME_AGREGA SIGLA_AGREGA  AGREGA  ESPVIDA  MORT1  T_ENV  \
# 0  2012  BRANCA      BRASIL       BRASIL       1    75.44  13.98  10.50
# 1  2013  BRANCA      BRASIL       BRASIL       1    75.70  13.38  10.61
# 2  2014  BRANCA      BRASIL       BRASIL       1    75.94  12.83  11.05
# 3  2015  BRANCA      BRASIL       BRASIL       1    76.18  12.31  11.22
# 4  2016  BRANCA      BRASIL       BRASIL       1    76.41  11.84  11.81
#
#    RAZDEP  ANOSEST  ...    POP25M    POP65M        POPT    POPTOT  \
# 0   45.48     8.51  ...  58928106   9718807         NaN  92576510
# 1   45.89     8.64  ...  59217765   9822998         NaN  92592040
# 2   45.08     8.82  ...  60751265  10302902         NaN  93243404
# 3   45.13     8.94  ...  60541205  10408799         NaN  92736266
# 4   45.30     9.09  ...  60137999  10734498  89842188.0  90918025
#
#    I_ESCOLARIDADE  I_FREQ_PROP  IDHM_E  IDHM_L  IDHM_R   IDHM
# 0           0.659        0.803   0.752   0.841     NaN    NaN
# 1           0.669        0.808   0.759   0.845     NaN    NaN
# 2           0.682        0.826   0.775   0.849     NaN    NaN
# 3           0.692        0.831   0.782   0.853     NaN    NaN
# 4           0.708        0.849   0.799   0.857   0.801  0.819
#
# [5 rows x 71 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 71 columns):
# Ano                  588 non-null int64
# COR                  588 non-null object
# NOME_AGREGA          588 non-null object
# SIGLA_AGREGA         588 non-null object
# AGREGA               588 non-null int64
# ESPVIDA              588 non-null float64
# MORT1                588 non-null float64
# T_ENV                588 non-null float64
# RAZDEP               588 non-null float64
# ANOSEST              588 non-null float64
# T_ANALF15M           588 non-null float64
# T_ANALF18M           588 non-null float64
# T_ANALF25M           588 non-null float64
# T_ATRASO_2_BASICO    588 non-null float64
# T_ATRASO_2_FUND      588 non-null float64
# T_FLBAS              588 non-null float64
# T_FLFUND             588 non-null float64
# T_FLMED              588 non-null float64
# T_FLSUPER            588 non-null float64
# T_FREQ5A6            588 non-null float64
# T_FREQ6A14           588 non-null float64
# T_FREQ15A17          588 non-null float64
# T_FREQ18A24          588 non-null float64
# T_FUND11A13          588 non-null float64
# T_FUND15A17          588 non-null float64
# T_FUND18M            588 non-null float64
# T_FUND18A24          588 non-null float64
# T_FUND25M            588 non-null float64
# T_MED18A20           588 non-null float64
# T_MED25M             588 non-null float64
# T_SUPER25M           588 non-null float64
# R1040                196 non-null float64
# R2040                196 non-null float64
# RDPC                 196 non-null float64
# V_RENOCUP            588 non-null float64
# RDPC1                196 non-null float64
# RDPC2                196 non-null float64
# RDPC3                196 non-null float64
# RDPC4                196 non-null float64
# RDPC5                196 non-null float64
# RDPC10               196 non-null float64
# RDPCT                196 non-null float64
# RIND                 196 non-null float64
# RMPOB                196 non-null float64
# RPOB                 196 non-null float64
# PRENTRAB             196 non-null float64
# PIND                 196 non-null float64
# PMPOB                196 non-null float64
# PPOB                 196 non-null float64
# GINI                 196 non-null float64
# THEIL                196 non-null float64
# POP                  196 non-null float64
# POP5A6               588 non-null int64
# POP6A14              588 non-null int64
# POP6A17              588 non-null int64
# POP11A13             588 non-null int64
# POP15A17             588 non-null int64
# POP15M               588 non-null int64
# POP18M               588 non-null int64
# POP18A20             588 non-null int64
# POP18A24             588 non-null int64
# POP25M               588 non-null int64
# POP65M               588 non-null int64
# POPT                 196 non-null float64
# POPTOT               588 non-null int64
# I_ESCOLARIDADE       588 non-null float64
# I_FREQ_PROP          588 non-null float64
# IDHM_E               588 non-null float64
# IDHM_L               588 non-null float64
# IDHM_R               196 non-null float64
# IDHM                 196 non-null float64
# dtypes: float64(54), int64(14), object(3)
# memory usage: 326.3+ KB

# %% [markdown]
# > Na quarta aba, temos 3 novas colunas, sendo duas colunas **a mais** do que na aba 3. </br>
# > Fazendo uma listagem rápida dos nomes das colunas das abas 3 e 4, é fácil identificar quais são as diferenças:
# > * Sai a coluna `COR` e entra a coluna `SEXO`;
# > * São adicionadas as colunas `IDHM_R_ajustado` e `IDHM_ajustado`;

# %%
idhm_data = pd.read_excel(file_path, sheet_name = 3) # verificando a quarta aba
idhm_data.head()
idhm_data.info()
# Out:
#     Ano   SEXO NOME_AGREGA SIGLA_AGREGA  AGREGA  ESPVIDA  MORT1  T_ENV  \
# 0  2012  HOMEM      BRASIL       BRASIL       1    70.91  15.69   7.86
# 1  2013  HOMEM      BRASIL       BRASIL       1    71.25  15.02   8.03
# 2  2014  HOMEM      BRASIL       BRASIL       1    71.57  14.40   8.34
# 3  2015  HOMEM      BRASIL       BRASIL       1    71.88  13.82   8.50
# 4  2016  HOMEM      BRASIL       BRASIL       1    72.18  13.29   8.75
#
#    RAZDEP  ANOSEST  ...        POPT    POPTOT  I_ESCOLARIDADE  I_FREQ_PROP  \
# 0   46.31     7.39  ...         NaN  96251861           0.585        0.697
# 1   46.41     7.50  ...         NaN  97187434           0.590        0.711
# 2   45.00     7.65  ...         NaN  97861023           0.604        0.732
# 3   44.35     7.80  ...         NaN  98805634           0.866        0.918
# 4   43.60     7.89  ...  98274414.0  99582016           0.630        0.763
#
#    IDHM_E  IDHM_L  IDHM_R  IDHM  IDHM_R_ajustado  IDHM_ajustado
# 0   0.657   0.765     NaN   NaN              NaN            NaN
# 1   0.668   0.771     NaN   NaN              NaN            NaN
# 2   0.687   0.776     NaN   NaN              NaN            NaN
# 3   0.900   0.781     NaN   NaN              NaN            NaN
# 4   0.716   0.786    0.75  0.75            0.818          0.772
#
# [5 rows x 73 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 73 columns):
# Ano                  588 non-null int64
# SEXO                 588 non-null object
# NOME_AGREGA          588 non-null object
# SIGLA_AGREGA         588 non-null object
# AGREGA               588 non-null int64
# ESPVIDA              588 non-null float64
# MORT1                588 non-null float64
# T_ENV                588 non-null float64
# RAZDEP               588 non-null float64
# ANOSEST              588 non-null float64
# T_ANALF15M           588 non-null float64
# T_ANALF18M           588 non-null float64
# T_ANALF25M           588 non-null float64
# T_ATRASO_2_BASICO    588 non-null float64
# T_ATRASO_2_FUND      588 non-null float64
# T_FLBAS              588 non-null float64
# T_FLFUND             588 non-null float64
# T_FLMED              588 non-null float64
# T_FLSUPER            588 non-null float64
# T_FREQ5A6            588 non-null float64
# T_FREQ6A14           588 non-null float64
# T_FREQ15A17          588 non-null float64
# T_FREQ18A24          588 non-null float64
# T_FUND11A13          588 non-null float64
# T_FUND15A17          588 non-null float64
# T_FUND18M            588 non-null float64
# T_FUND18A24          588 non-null float64
# T_FUND25M            588 non-null float64
# T_MED18A20           588 non-null float64
# T_MED25M             588 non-null float64
# T_SUPER25M           588 non-null float64
# R1040                196 non-null float64
# R2040                196 non-null float64
# RDPC                 196 non-null float64
# V_RENOCUP            588 non-null float64
# RDPC1                196 non-null float64
# RDPC2                196 non-null float64
# RDPC3                196 non-null float64
# RDPC4                196 non-null float64
# RDPC5                196 non-null float64
# RDPC10               196 non-null float64
# RDPCT                196 non-null float64
# RIND                 196 non-null float64
# RMPOB                196 non-null float64
# RPOB                 196 non-null float64
# PRENTRAB             196 non-null float64
# PIND                 196 non-null float64
# PMPOB                196 non-null float64
# PPOB                 196 non-null float64
# GINI                 196 non-null float64
# THEIL                196 non-null float64
# POP                  196 non-null float64
# POP5A6               588 non-null int64
# POP6A14              588 non-null int64
# POP6A17              588 non-null int64
# POP11A13             588 non-null int64
# POP15A17             588 non-null int64
# POP15M               588 non-null int64
# POP18M               588 non-null int64
# POP18A20             588 non-null int64
# POP18A24             588 non-null int64
# POP25M               588 non-null int64
# POP65M               588 non-null int64
# POPT                 196 non-null float64
# POPTOT               588 non-null int64
# I_ESCOLARIDADE       588 non-null float64
# I_FREQ_PROP          588 non-null float64
# IDHM_E               588 non-null float64
# IDHM_L               588 non-null float64
# IDHM_R               196 non-null float64
# IDHM                 196 non-null float64
# IDHM_R_ajustado      196 non-null float64
# IDHM_ajustado        196 non-null float64
# dtypes: float64(56), int64(14), object(3)
# memory usage: 335.5+ KB

# %% [markdown]
# > Vou jogar cada planilha em um objeto para facilitar os códigos futuros.

# %%
summary_plan = pd.read_excel(file_path, sheet_name = 0)
general_plan = pd.read_excel(file_path, sheet_name = 1)
ethnicity_plan = pd.read_excel(file_path, sheet_name = 2)
gender_plan = pd.read_excel(file_path, sheet_name = 3)

# %% [markdown]
# > Listando os nomes das colunas para facilitar a comparação visual

# %%
ethnicity_plan.columns # listando as colunas da aba 3
gender_plan.columns # listando as colunas da aba 4
# Out:
# Index(['Ano', 'COR', 'NOME_AGREGA', 'SIGLA_AGREGA', 'AGREGA', 'ESPVIDA',
#        'MORT1', 'T_ENV', 'RAZDEP', 'ANOSEST', 'T_ANALF15M', 'T_ANALF18M',
#        'T_ANALF25M', 'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND', 'T_FLBAS',
#        'T_FLFUND', 'T_FLMED', 'T_FLSUPER', 'T_FREQ5A6', 'T_FREQ6A14',
#        'T_FREQ15A17', 'T_FREQ18A24', 'T_FUND11A13', 'T_FUND15A17', 'T_FUND18M',
#        'T_FUND18A24', 'T_FUND25M', 'T_MED18A20', 'T_MED25M', 'T_SUPER25M',
#        'R1040', 'R2040', 'RDPC', 'V_RENOCUP', 'RDPC1', 'RDPC2', 'RDPC3',
#        'RDPC4', 'RDPC5', 'RDPC10', 'RDPCT', 'RIND', 'RMPOB', 'RPOB',
#        'PRENTRAB', 'PIND', 'PMPOB', 'PPOB', 'GINI', 'THEIL', 'POP', 'POP5A6',
#        'POP6A14', 'POP6A17', 'POP11A13', 'POP15A17', 'POP15M', 'POP18M',
#        'POP18A20', 'POP18A24', 'POP25M', 'POP65M', 'POPT', 'POPTOT',
#        'I_ESCOLARIDADE', 'I_FREQ_PROP', 'IDHM_E', 'IDHM_L', 'IDHM_R', 'IDHM'],
#       dtype='object')
# Index(['Ano', 'SEXO', 'NOME_AGREGA', 'SIGLA_AGREGA', 'AGREGA', 'ESPVIDA',
#        'MORT1', 'T_ENV', 'RAZDEP', 'ANOSEST', 'T_ANALF15M', 'T_ANALF18M',
#        'T_ANALF25M', 'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND', 'T_FLBAS',
#        'T_FLFUND', 'T_FLMED', 'T_FLSUPER', 'T_FREQ5A6', 'T_FREQ6A14',
#        'T_FREQ15A17', 'T_FREQ18A24', 'T_FUND11A13', 'T_FUND15A17', 'T_FUND18M',
#        'T_FUND18A24', 'T_FUND25M', 'T_MED18A20', 'T_MED25M', 'T_SUPER25M',
#        'R1040', 'R2040', 'RDPC', 'V_RENOCUP', 'RDPC1', 'RDPC2', 'RDPC3',
#        'RDPC4', 'RDPC5', 'RDPC10', 'RDPCT', 'RIND', 'RMPOB', 'RPOB',
#        'PRENTRAB', 'PIND', 'PMPOB', 'PPOB', 'GINI', 'THEIL', 'POP', 'POP5A6',
#        'POP6A14', 'POP6A17', 'POP11A13', 'POP15A17', 'POP15M', 'POP18M',
#        'POP18A20', 'POP18A24', 'POP25M', 'POP65M', 'POPT', 'POPTOT',
#        'I_ESCOLARIDADE', 'I_FREQ_PROP', 'IDHM_E', 'IDHM_L', 'IDHM_R', 'IDHM',
#        'IDHM_R_ajustado', 'IDHM_ajustado'],
#       dtype='object')

# %% [markdown]
# > Como já sabemos, o número de observaçõs por coluna das duas abas é igual (588), mudando apenas o número de colunas. Isso significa que os valores serão os mesmos? Não. </br>
# > Isso acontece, pois o **contexto** de cada aba é diferente, onde uma está olhando para um panorama relativo à `COR` e a outra aba um contexto relativo ao  `SEXO`.
# > > OBS: toda vez que retornamos uma dimensionalidade, seja de um DataFrame ou de uma Array/Matriz (trataremos posteriormente), é retornada uma [tupla](https://excript.com/python/tuplas-python.html) com dois números, sendo o primeiro o número de linhas e o segundo o número de colunas.

# %%
ethnicity_plan.shape # dimensionalidade da aba 1
gender_plan.shape # dimensionalidade da aba 2
# Out:
# (588, 71)
# (588, 73)

# %% [markdown]
# > Analisando com mais calma os índices, decidi tirar algumas variáveis para tornar a base mais enxuta. Um dos critérios que usei, foi retirar todas as variávies que são taxas, percentuais ou cálculos relativos às outras variáveis, algo que podemos fazer na mão posteriormente.

# %%
pd.set_option('display.max_rows', 70)
summary_plan
# Out:
#                 SIGLA                                         NOME CURTO  \
# 0                 ANO                                                ANO
# 1              AGREGA                       Codigo interno identificador
# 2             ESPVIDA                       Esperança de vida ao nascer
# 3               MORT1                               Mortalidade infantil
# 4               T_ENV                             Taxa de envelhecimento
# 5              RAZDEP                               Razão de dependência
# 6             ANOSEST                            Média de anos de estudo
# 7          T_ANALF15M           Taxa de analfabetismo - 15 anos ou mais
# 8          T_ANALF18M           Taxa de analfabetismo - 18 anos ou mais
# 9          T_ANALF25M            Taxa de analfabetismo - 25 anos ou mais
# 10  T_ATRASO_2_BASICO  % de 6 a 17 anos no básico com 2 anos ou mais ...
# 11    T_ATRASO_2_FUND  % de 6 a 14 anos no fundamental com 2 anos ou ...
# 12            T_FLBAS  Taxa de frequência líquida ao básico REGULAR S...
# 13           T_FLFUND  Taxa de frequência líquida ao fundamental REGU...
# 14            T_FLMED  Taxa de frequência líquida ao médio REGULAR SE...
# 15          T_FLSUPER             Taxa de frequência líquida ao superior
# 16          T_FREQ5A6                          % de 5 a 6 anos na escola
# 17         T_FREQ6A14                         % de 6 a 14 anos na escola
# 18        T_FREQ15A17                        % de 15 a 17 anos na escola
# 19        T_FREQ18A24                        % de 18 a 24 anos na escola
# 20        T_FUND11A13  % de 11 a 13 anos nos anos finais do fundament...
# 21        T_FUND15A17         % de 15 a 17 anos com fundamental completo
# 22          T_FUND18M      % de 18 anos ou mais com fundamental completo
# 23        T_FUND18A24         % de 18 a 24 anos com fundamental completo
# 24          T_FUND25M      % de 25 anos ou mais com fundamental completo
# 25         T_MED18A20               % de 18 a 20 anos com médio completo
# 26           T_MED25M            % de 25 anos ou mais com médio completo
# 27         T_SUPER25M         % de 25 anos ou mais com superior completo
# 28              R1040             Razão 10% mais ricos / 40% mais pobres
# 29              R2040             Razão 20% mais ricos / 40% mais pobres
# 30               RDPC                                  Renda per capita
# 31          V_RENOCUP                            Renda média do trabalho
# 32              RDPC1     Renda per capita média do 1º quinto mais pobre
# 33              RDPC2     Renda per capita média do 2º quinto mais pobre
# 34              RDPC3     Renda per capita média do 3º quinto mais pobre
# 35              RDPC4     Renda per capita média do 4º quinto mais pobre
# 36              RDPC5         Renda per capita média do quinto mais rico
# 37             RDPC10         Renda per capita média do décimo mais rico
# 38              RDPCT               Renda per capita , exceto renda nula
# 39               RIND           Renda per capita dos extremamente pobres
# 40              RMPOB                        Renda per capita dos pobres
# 41               RPOB         Renda per capita dos vulneráveis à pobreza
# 42           PRENTRAB  % da renda proveniente de rendimentos do trabalho
# 43               PIND                           % de extremamente pobres
# 44              PMPOB                                        % de pobres
# 45               PPOB                         % de vulneráveis à pobreza
# 46               GINI                                     Índice de Gini
# 47              THEIL                                Índice de Theil - L
# 48                POP  População total em domicílios particulares per...
# 49             POP5A6                            População de 5 a 6 anos
# 50            POP6A14                           População de 6 a 14 anos
# 51            POP6A17                           População de 6 a 17 anos
# 52           POP11A13                          População de 11 a 13 anos
# 53           POP15A17                          População de 15 a 17 anos
# 54             POP15M                       População de 15 anos ou mais
# 55             POP18M                       População de 18 anos ou mais
# 56           POP18A20                          População de 18 a 20 anos
# 57           POP18A24                          População de 18 a 24 anos
# 58             POP25M                       População de 25 anos ou mais
# 59             POP65M                       População de 65 anos ou mais
# 60               POPT  População total em domicílios particulares per...
# 61             POPTOT                                    População total
# 62     I_ESCOLARIDADE          Subíndice de escolaridade - IDHM Educação
# 63        I_FREQ_PROP    Subíndice de frequência escolar - IDHM Educação
# 64             IDHM_E                                      IDHM Educação
# 65             IDHM_L                                   IDHM Longevidade
# 66             IDHM_R                                         IDHM Renda
# 67               IDHM                                               IDHM
#
#                                            NOME LONGO  \
# 0                                                 ANO
# 1                        Codigo interno identificador
# 2                         Esperança de vida ao nascer
# 3                     Mortalidade até um ano de idade
# 4                              Taxa de envelhecimento
# 5   Percentual da população de menos de 15 anos e ...
# 6   Média de anos de estudo das pessoas de 25 anos...
# 7   Taxa de analfabetismo da população de 15 anos ...
# 8   Taxa de analfabetismo da população de 18 anos ...
# 9   Taxa de analfabetismo da população de 25 anos ...
# 10  Percentual da população de 6 a 17 anos de idad...
# 11  Percentual da população de 6 a 14 anos de idad...
# 12  Taxa de frequência líquida ao ensino   básico ...
# 13  Taxa de frequência líquida ao ensino   fundame...
# 14  Taxa de frequência líquida ao ensino   médio R...
# 15    Taxa de frequência líquida ao ensino   superior
# 16  Percentual da população de 5 a 6 anos de idade...
# 17  Taxa de atendimento escolar da população de 6 ...
# 18  Taxa de atendimento escolar da população de 15...
# 19  Taxa de atendimento escolar da população de 18...
# 20  Percentual da população de 11 a 13 anos de ida...
# 21  Percentual da população de 15 a 17 anos com fu...
# 22  Percentual da população de 18 anos ou mais com...
# 23  Percentual da população de 18 a 24 anos com fu...
# 24  Percentual da população de 25 anos ou mais com...
# 25  Percentual da população de 18 a 20 anos de ida...
# 26  Percentual da população de 25 anos ou mais com...
# 27  Percentual da população de 25 anos ou mais com...
# 28             Razão 10% mais ricos / 40% mais pobres
# 29             Razão 20% mais ricos / 40% mais pobres
# 30                             Renda per capita média
# 31       Renda média do trabalho das pessoas ocupadas
# 32  Renda domiciliar per capita média do quinto ma...
# 33  Renda domiciliar per capita  média do 2º quint...
# 34  Renda domiciliar per capita  média do 3º quint...
# 35  Renda domiciliar per capita  média do 4º quint...
# 36  Renda domiciliar per capita média do quinto ma...
# 37  Renda domiciliar per capita média do décimo ma...
# 38  Renda domiciliar per capita média, exceto rend...
# 39  Renda domiciliar per capita média dos extremam...
# 40       Renda domiciliar per capita média dos pobres
# 41  Renda domiciliar per capita média dos vulnerav...
# 42  Percentual da renda proveniente de rendimentos...
# 43                   Proporção de extremamente pobres
# 44                                Proporção de pobres
# 45                 Proporção de vulneráveis à pobreza
# 46                                     Índice de Gini
# 47                                Índice de Theil - L
# 48  População total que reside em domicílios parti...
# 49                  População de 5 a 6  anos de idade
# 50                  População de 6 a 14 anos de idade
# 51                  População de 6 a 17 anos de idade
# 52                 População de 11 a 13 anos de idade
# 53                 População de 15 a 17 anos de idade
# 54              População de 15 anos ou mais de idade
# 55              População de 18 anos ou mais de idade
# 56                 População de 18 a 20 anos de idade
# 57                 População de 18 a 24 anos de idade
# 58              População de 25 anos ou mais de idade
# 59              População de 65 anos ou mais de idade
# 60  População total que reside em domicílios parti...
# 61                                    População total
# 62  Subíndice de escolaridade da população adulta ...
# 63  Subíndice de frequência escolar da população j...
# 64  Índice de Desenvolvimento Humano Municipal - D...
# 65  Índice de Desenvolvimento Humano Municipal  - ...
# 66  Índice de Desenvolvimento Humano Municipal - D...
# 67         Índice de Desenvolvimento Humano Municipal
#
#                                             DEFINIÇÃO
# 0                                                 ANO
# 1                        Codigo interno identificador
# 2   Número médio de anos que as pessoas deverão vi...
# 3   Número de crianças que não deverão sobreviver ...
# 4   Razão entre a população de 65 anos ou mais de ...
# 5   Razão de dependência é medida pela razão entre...
# 6   Razão entre o somatório do número de anos de e...
# 7   Razão entre a população de 15 anos ou mais de ...
# 8   Razão entre a população de 18 anos ou mais de ...
# 9   Razão entre a população de 25 anos ou mais de ...
# 10  Razão entre o número de pessoas de 6 a 17 anos...
# 11  Razão entre o número de pessoas de 6 a 14 anos...
# 12  Razão entre o número de pessoas na faixa etári...
# 13  Razão entre o número de pessoas na faixa etári...
# 14  Razão entre o número de pessoas na faixa etári...
# 15  Razão entre o número de pessoas na faixa etári...
# 16  Razão entre a população de 5 a 6 anos de idade...
# 17  Razão entre a população de 6 a 14 anos de idad...
# 18  Razão entre a população de 15 a 17 anos de ida...
# 19  Razão entre a população de 18 a 24 anos de ida...
# 20  Razão entre a população de 11 a 13 anos de ida...
# 21  Razão entre a população de 15 a 17 anos de ida...
# 22  Razão entre a população de 18 anos ou mais de ...
# 23  Razão entre a população de 18 a 24 anos de ida...
# 24  Razão entre a população de 25 anos ou mais de ...
# 25  Razão entre a população de 18 a 20 anos de ida...
# 26  Razão entre a população de 25 anos ou mais de ...
# 27  Razão entre a população de 25 anos ou mais de ...
# 28  Medida do grau de desigualdade existente na di...
# 29  Medida do grau de desigualdade existente na di...
# 30  Razão entre o somatório da renda de todos os i...
# 31  Razão entre o rendimento bruto efetivo mensal ...
# 32  Média da renda domiciliar per capita dos indiv...
# 33  Média da renda domiciliar per capita dos indiv...
# 34  Média da renda domiciliar per capita dos indiv...
# 35  Média da renda domiciliar per capita dos indiv...
# 36  Média da renda domiciliar per capita dos indiv...
# 37  Média da renda domiciliar per capita dos indiv...
# 38  Razão entre o somatório da renda domiciliar pe...
# 39  Média da renda domiciliar per capita das pesso...
# 40  Média da renda domiciliar per capita das pesso...
# 41  Média da renda domiciliar per capita das pesso...
# 42  Participação percentual das rendas proveniente...
# 43  Proporção dos indivíduos com renda domiciliar ...
# 44  Proporção dos indivíduos com renda domiciliar ...
# 45  Proporção dos indivíduos com renda domiciliar ...
# 46  Mede o grau de desigualdade existente na distr...
# 47  Mede a desigualdade na distribuição de indivíd...
# 48  População residente em domicílios particulares...
# 49             População residente nessa faixa etária
# 50             População residente nessa faixa etária
# 51             População residente nessa faixa etária
# 52             População residente nessa faixa etária
# 53             População residente nessa faixa etária
# 54             População residente nessa faixa etária
# 55             População residente nessa faixa etária
# 56             População residente nessa faixa etária
# 57             População residente nessa faixa etária
# 58             População residente nessa faixa etária
# 59             População residente nessa faixa etária
# 60  Refere-se à população residente em domicílios ...
# 61                          População residente total
# 62  Subíndice que compõe o IDHM Educação, represen...
# 63  Subíndice que compõe o IDHM Educação, represen...
# 64  Índice sintético da dimensão Educação,  é um d...
# 65  Índice da dimensão Longevidade, é um dos 3 índ...
# 66  Índice da dimensão Renda, é um dos 3 índices q...
# 67  Índice de Desenvolvimento Humano Municipal. Mé...

# %% [markdown]
# <center> <h2> Preparando a Base  </h2> </center>

# %% [markdown]
# > Abaixo, irei separar as variáveis para fazer o *split* do que vou usar. </br>
# > Como temos duas variáveis a mais na `ethnicity_plan` (`'IDHM_R_ajustado'`, `'IDHM_ajustado'`), é mais fácil eu selecionar as variáveis que não quero utilizar `ethnicity_plan` e `gender_plan` e fazer um *drop* (remover).

# %%
vars = summary_plan

# visualizando os rótulos das colunas como lista
# podemos separar as variáveis a serem utilizadas 
# ou retiradas apenas mandando-as para um objeto

# criando uma lista com os rótutos (variáveis)
# e "mandando-os" para o objeto final_vars
vars_out = [
       'T_ENV', 'RAZDEP', 'ANOSEST','T_ANALF15M', 'T_ANALF18M', 'T_ANALF25M', 
       'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND', 'T_FLBAS', 'T_FLFUND', 'T_FLMED',
       'T_FLSUPER', 'T_FREQ5A6', 'T_FREQ6A14', 'T_FREQ15A17', 'T_FREQ18A24',
       'T_FUND11A13', 'T_FUND15A17', 'T_FUND18M', 'T_FUND18A24', 'T_FUND25M',
       'T_MED18A20', 'T_MED25M', 'T_SUPER25M', 'R1040', 'R2040', 'RDPC1', 
       'RDPC2', 'RDPC3', 'RDPC4', 'RDPC5', 'RDPC10', 'RDPCT', 'RIND', 'RMPOB', 
       'RPOB', 'PRENTRAB', 'PIND', 'PMPOB', 'PPOB', 'GINI', 'THEIL',
       'I_ESCOLARIDADE', 'I_FREQ_PROP', 'IDHM_E', 'IDHM_L', 'IDHM_R','IDHM',
       ]

# %% [markdown]
# > Escolhidas as variáveis que irei deixar na base final, basta retirar essas colunas de cada uma das planilhas. Porém, temos um problema. O que fazer com as planilhas de cor e sexo? Escolher apenas uma das duas? Fazer uma junção de ambas? </br>
# > Poderíamos fazer alguma média ponderada, um *stack* (empilhamento) adaptado, entre outras técnias de *merge*, mas, para facilitar as coisas, vou dropar as colunas e criar duas bases, uma no contexto da análise de `COR` e a outra no contexto da análise de `SEXO`.

# %%
# removendo as colunas de ethnicity_plan
vars_ethnicity_plan = ethnicity_plan.drop(vars_out, axis = 1)

# removendo as colunas de gender_plan
vars_gender_plan = gender_plan.drop(vars_out, axis = 1)
# removendo as colunas que sobraram de gender_plan
vars_gender_plan = vars_gender_plan.drop(['IDHM_R_ajustado', 'IDHM_ajustado'], axis = 1)

# %%
# verificando o formato dos dataframes
vars_ethnicity_plan.shape
vars_gender_plan.shape
# Out:
# (588, 23)
# (588, 23)

# %%
# verificando, de forma visual, se todas as colunas batem
vars_ethnicity_plan.columns
vars_gender_plan.columns
# Out:
# Index(['Ano', 'COR', 'NOME_AGREGA', 'SIGLA_AGREGA', 'AGREGA', 'ESPVIDA',
#        'MORT1', 'RDPC', 'V_RENOCUP', 'POP', 'POP5A6', 'POP6A14', 'POP6A17',
#        'POP11A13', 'POP15A17', 'POP15M', 'POP18M', 'POP18A20', 'POP18A24',
#        'POP25M', 'POP65M', 'POPT', 'POPTOT'],
#       dtype='object')
# Index(['Ano', 'SEXO', 'NOME_AGREGA', 'SIGLA_AGREGA', 'AGREGA', 'ESPVIDA',
#        'MORT1', 'RDPC', 'V_RENOCUP', 'POP', 'POP5A6', 'POP6A14', 'POP6A17',
#        'POP11A13', 'POP15A17', 'POP15M', 'POP18M', 'POP18A20', 'POP18A24',
#        'POP25M', 'POP65M', 'POPT', 'POPTOT'],
#       dtype='object')

# %% [markdown]
# > Para não termos que fazer todo esse processo sempre que começarmos um novo Notebook para análises ou ter que salvar apenas os dados separados em um novo arquivo csv, o que pode dificultar possíveis verificações mais tarde, automatizei o processo de preprocessamento dessa base em específico. </br>
# > A função encontra-se abaixo e também a transformarei em um módulo, o qual irei importar futuramente.

# %%
class PreprocessingData:
    
    def preprocessing_base(file):
        summary_plan = pd.read_excel(file_path, sheet_name = 0)
        ethnicity_plan = pd.read_excel(file, sheet_name = 2)
        gender_plan = pd.read_excel(file, sheet_name = 3)
        
        vars_out = [
            'T_ENV', 'RAZDEP', 'ANOSEST','T_ANALF15M', 'T_ANALF18M', 'T_ANALF25M', 
           'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND', 'T_FLBAS', 'T_FLFUND', 'T_FLMED',
           'T_FLSUPER', 'T_FREQ5A6', 'T_FREQ6A14', 'T_FREQ15A17', 'T_FREQ18A24',
           'T_FUND11A13', 'T_FUND15A17', 'T_FUND18M', 'T_FUND18A24', 'T_FUND25M',
           'T_MED18A20', 'T_MED25M', 'T_SUPER25M', 'R1040', 'R2040', 'RDPC1', 
           'RDPC2', 'RDPC3', 'RDPC4', 'RDPC5', 'RDPC10', 'RDPCT', 'RIND', 'RMPOB', 
           'RPOB', 'PRENTRAB', 'PIND', 'PMPOB', 'PPOB', 'GINI', 'THEIL',
           'I_ESCOLARIDADE', 'I_FREQ_PROP', 'IDHM_E', 'IDHM_L', 'IDHM_R','IDHM',
           ]
        
        vars_ethnicity_plan = ethnicity_plan.drop(vars_out, axis = 1)
        vars_gender_plan = gender_plan.drop(vars_out, axis = 1)
        vars_gender_plan = vars_gender_plan.drop(['IDHM_R_ajustado', 'IDHM_ajustado'], axis = 1)
        
        return summary_plan, vars_ethnicity_plan, vars_gender_plan

# %%
from utils.tools import PreprocessingData

pp = PreprocessingData

file_path = 'datasets/idhm_pnadc_2012_2108.xlsx'
summary_plan, ethnicity_plan, gender_plan = pp.preprocessing_base(file_path)
